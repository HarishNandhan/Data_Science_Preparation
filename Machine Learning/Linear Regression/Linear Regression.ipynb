# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('Area in Sq. ft')
plt.ylabel('Price in $')
plt.scatter(df.area, df.price, color = 'red', marker = '+')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[2000]])
# Out:
# C:\Users\yoges\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([452191.78082192])

# %% [markdown]
# ###  y  = mx+c

# %%
reg.coef_ # m
# Out:
# array([135.78767123])

# %%
reg.intercept_ # c
# Out:
# 180616.43835616432

# %%
135.78767123*2000 + 180616.43835616432
# Out:
# 452191.78081616433

# %% [markdown]
# ### Plotting the Regression Line

# %%
# %matplotlib inline
plt.xlabel('Area in Sq. ft', fontsize = 20)
plt.ylabel('Price in $', fontsize = 20)
plt.scatter(df.area, df.price, color = 'red', marker = '+')
plt.plot(df.area, reg.predict(df[['area']]), color = 'blue')

# %%
import pandas as pd
import numpy as np

random_values = np.random.randint(2500, 8501, size=10)

df = pd.DataFrame({'area': random_values})

df.to_csv('area.csv', index=False)

print("area.csv has been created with the following data:")
print(df)
# Out:
# area.csv has been created with the following data:
#    area
# 0  6342
# 1  5002
# 2  7900
# 3  3808
# 4  7867
# 5  5442
# 6  5024
# 7  3481
# 8  5520
# 9  8026

# %%
df.head()
# Out:
#    area
# 0  6342
# 1  5002
# 2  7900
# 3  3808
# 4  7867

# %%
 p = reg.predict(df)

# %%
df['prices'] = p

# %%
df.to_csv("prediction.csv",index=False)

# %% [markdown]
# ## HOMEWORK EXERCISE

# %% [markdown]
# Predict canada's per capita income in year 2020. There is an exercise folder here on github at same level as this notebook, download that and you will find canada_per_capita_income.csv file. Using this build a regression model and predict the per capita income fo canadian citizens in year 2020

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model

inc = pd.read_csv('canada_per_capita_income.csv')
inc.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
inc.rename(columns={'per capita income (US$)' : 'percapita income'}, inplace = True)

# %%
inc.head()
# Out:
#    year  percapita income
# 0  1970       3399.299037
# 1  1971       3768.297935
# 2  1972       4251.175484
# 3  1973       4804.463248
# 4  1974       5576.514583

# %%
# %matplotlib inline
plt.xlabel('Year')
plt.ylabel('Percapita income in $')
plt.scatter(inc.year, inc['percapita income'], color = 'red', marker = '+')
plt.plot(inc.year, reg.predict(inc[['year']]), color = 'blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(inc[['year']],inc['percapita income'])
# Out:
# LinearRegression()

# %%
reg.predict([[2020]])
# Out:
# C:\Users\yoges\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([41288.69409442])
